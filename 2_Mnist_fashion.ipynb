# %%
# !pip install -U tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (4.5.2)
# Requirement already satisfied: promise in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: importlib-resources in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (5.4.0)
# Requirement already satisfied: typing-extensions in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (3.7.4.3)
# Requirement already satisfied: tqdm in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (4.64.0)
# Requirement already satisfied: tensorflow-metadata in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.2.0)
# Requirement already satisfied: termcolor in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: numpy in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.19.5)
# Requirement already satisfied: absl-py in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (0.12.0)
# Requirement already satisfied: dataclasses in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (0.8)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (3.19.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (2.27.1)
# Requirement already satisfied: six in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.16.0)
# Requirement already satisfied: dill in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (1.26.9)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from importlib-resources->tensorflow_datasets) (3.6.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.56.3)
# Requirement already satisfied: colorama in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from tqdm->tensorflow_datasets) (0.4.4)

# %%
from __future__ import absolute_import, division, print_function

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (7.7.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipywidgets) (7.16.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipywidgets) (1.1.2)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipywidgets) (3.6.2)
# Requirement already satisfied: jupyter-client in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.2)
# Requirement already satisfied: tornado>=4.2 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: decorator in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pygments in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: colorama in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: backcall in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.17.0)
# Requirement already satisfied: pickleshare in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: parso>=0.7.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from traitlets>=4.3.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.9.4)
# Requirement already satisfied: nbconvert in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (22.2.1)
# Requirement already satisfied: nbformat in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.1.3)
# Requirement already satisfied: prometheus-client in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.8.1)
# Requirement already satisfied: entrypoints in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (228)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.3)
# Requirement already satisfied: testpath in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: async-generator in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.3)
# Requirement already satisfied: packaging in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3)
# Requirement already satisfied: webencodings in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\meghavi computers\.conda\envs\deepl\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.9)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import math
import numpy as np
import matplotlib.pyplot as plt
# progress bar
import tqdm
import tqdm.auto
tqdm.tqdm = tqdm.auto.tqdm

# %%
dataset, metadata = tfds.load('fashion_mnist',as_supervised=True,with_info=True)

# %%
train_dataset,test_dataset = dataset['train'],dataset['test']

# %%
train_dataset
# Out:
# <PrefetchDataset shapes: ((28, 28, 1), ()), types: (tf.uint8, tf.int64)>

# %%
test_dataset
# Out:
# <PrefetchDataset shapes: ((28, 28, 1), ()), types: (tf.uint8, tf.int64)>

# %%
type(train_dataset)
# Out:
# tensorflow.python.data.ops.dataset_ops.PrefetchDataset

# %%
class_names = ['T-shirt/Top','Trouser','Pullover','Dress','Coat','Sandal','Shirt',
              'Sneaker','Bag','Ankel_boot']

# %%
class_names
# Out:
# ['T-shirt/Top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankel_boot']

# %%
num_training_examples = metadata.splits['train'].num_examples
num_testing_examples = metadata.splits['test'].num_examples

# %%
num_testing_examples
# Out:
# 10000

# %%
num_training_examples
# Out:
# 60000

# %%
print("Numbers of training Examples: {}".format(num_training_examples))
print("Numbers of testing Examples: {}".format(num_testing_examples))
# Out:
# Numbers of training Examples: 60000
# Numbers of testing Examples: 10000

# %%
def normalize(images,labels):
    images = tf.cast(images,tf.float32)
    images /= 255
    return images,labels

# %%
train_dataset = train_dataset.map(normalize)
test_dataset = test_dataset.map(normalize)

# %%
for image,label in test_dataset.take(1):
    break
image = image.numpy().reshape((28,28))
plt.figure()
plt.imshow(image,cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
i = 0
for (image,label) in test_dataset.take(25):
    image = image.numpy().reshape((28,28))
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image,cmap=plt.cm.binary)
    plt.xlabel(class_names[label])
    i+=1
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
BATCH_SIZE = 32

# %%
train_dataset = train_dataset.repeat().shuffle(num_training_examples).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
model.fit(train_dataset,epochs=25,steps_per_epoch=math.ceil(num_training_examples/BATCH_SIZE))
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 14s 4ms/step - loss: 0.4924 - accuracy: 0.8269
# Epoch 2/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3702 - accuracy: 0.8654
# Epoch 3/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3359 - accuracy: 0.8782
# Epoch 4/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3109 - accuracy: 0.8870
# Epoch 5/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2920 - accuracy: 0.8930
# Epoch 6/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2749 - accuracy: 0.8986
# Epoch 7/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2628 - accuracy: 0.9019
# Epoch 8/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2566 - accuracy: 0.9051
# Epoch 9/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2463 - accuracy: 0.9087
# Epoch 10/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2372 - accuracy: 0.9119
# Epoch 11/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2257 - accuracy: 0.9151
# Epoch 12/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2233 - accuracy: 0.9154
# Epoch 13/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2152 - accuracy: 0.9194
# Epoch 14/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2029 - accuracy: 0.9241
# Epoch 15/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2052 - accuracy: 0.9233
# Epoch 16/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1978 - accuracy: 0.9265
# Epoch 17/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1893 - accuracy: 0.9291
# Epoch 18/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1849 - accuracy: 0.9311
# Epoch 19/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1808 - accuracy: 0.9313
# Epoch 20/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1790 - accuracy: 0.9327
# Epoch 21/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1704 - accuracy: 0.9365
# Epoch 22/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1670 - accuracy: 0.9376
# Epoch 23/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1645 - accuracy: 0.9384
# Epoch 24/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1622 - accuracy: 0.9391
# Epoch 25/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1521 - accuracy: 0.9434

# %%
test_loss, test_accuracy = model.evaluate(test_dataset,steps=math.ceil(num_testing_examples/BATCH_SIZE))
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3902 - accuracy: 0.8834

# %%
for test_images,test_labels in test_dataset.take(1):
    test_images = test_images.numpy()
    test_labels = test_labels.numpy()
    predictions = model.predict(test_images)

# %%
predictions.shape
# Out:
# (32, 10)

# %%
predictions[0]
# Out:
# array([1.7053020e-09, 1.0852603e-07, 3.8576865e-04, 1.1073192e-08,
#        9.9746847e-01, 5.6992310e-16, 2.1455947e-03, 1.3898734e-18,
#        5.9240429e-10, 1.6298777e-14], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 4

# %%
np.argmax(predictions[0])
np.argmax(predictions[0])
# Out:
# 4

# %%
def plot_image(i,predictions_array, true_labels,images):
    predictions_array,true_labels,img = predictions_array[i],true_labels[i],images[i]
    plt.grid(False)
    plt.yticks([])
    plt.xticks([])
    plt.imshow(img[...,0],cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_labels:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel('{} {:2.0f}% ({})'.format(class_names[predicted_label],100*np.max(predictions_array),class_names[true_labels]),color=color)

# %%
def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1]) 
  predicted_label = np.argmax(predictions_array)
  
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i,predictions,test_labels,test_images)
plt.subplot(1,2,2)
plot_value_array(i,predictions,test_labels)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols,2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows,2*num_cols,2*i+1)
    plot_image(i,predictions,test_labels,test_images)
    plt.subplot(num_rows,2*num_cols,2*i+2)
    plot_value_array(i,predictions,test_labels)

# %%
img = test_images[0]
print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = np.array([img])
print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
prediction_single = model.predict(img)
print(prediction_single)
# Out:
# [[1.70530201e-09 1.08526031e-07 3.85768828e-04 1.10731495e-08
#   9.97468472e-01 5.69923101e-16 2.14560097e-03 1.38986278e-18
#   5.92403182e-10 1.62987774e-14]]

# %%
plot_value_array(0,prediction_single,test_labels)
_ = plt.xticks(range(10),class_names,rotation=45)
